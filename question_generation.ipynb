# %% [markdown]
# <a href="https://colab.research.google.com/github/kharchoufiabdelkarim/abstractivesummary/blob/main/question_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers==3.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 754 kB 11.4 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 62.4 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 60.0 MB/s
# ...
#      |████████████████████████████████| 880 kB 57.3 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=bc154e722cb784f00f0af01a9fbf558d7adabcfbd20e0ea31afb0e2ffb01a2ea
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...

# %%
# !python -m nltk.downloader punkt
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !git clone https://github.com/patil-suraj/question_generation.git
# Out:
# Cloning into 'question_generation'...
# remote: Enumerating objects: 268, done.
# remote: Total 268 (delta 0), reused 0 (delta 0), pack-reused 268
# Receiving objects: 100% (268/268), 299.04 KiB | 8.54 MiB/s, done.
# Resolving deltas: 100% (140/140), done.

# %% [markdown]
# ## Single task QA

# %%
# %cd question_generation
# Out:
# /content/question_generation

# %%
from pipelines import pipeline

# %%
nlp = pipeline("question-generation")
# Out:
# Downloading:   0%|          | 0.00/627 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/656 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %%
nlp(text3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c5d27d76fc3b> in <module>()
# ----> 1 nlp(text3)
#
# NameError: name 'text3' is not defined

# %% [markdown]
# If you want to use the t5-base model, then pass the path through model parameter

# %% [markdown]
# ### small-model

# %%
import pandas as pd
df=pd.read_csv('/content/newmeqsum.csv')
df
# Out:
#      Unnamed: 0                                           document  \
# 0             0   who and where to get the d i need want to kno...
# 1             1  who makes medicine i am wondering what company...
# 2             2   hey hello can you tell me where do i order th...
# 3             3  williams syndrome i would like to have my daug...
# 4             4  clinicaltrials to question general information...
# ..          ...                                                ...
# 995         995   after surgery of ear drum still same problem ...
# 996         996   clinicaltrials to question specific study loo...
# 997         997   i have been tingling in my lower right arm fr...
# 998         998   sleep coma i was diagnosed with sleep and i h...
# 999         999   home resources for old people what specific r...
#
#                                                summary
# 0                         who manufactures cetirizine
# ...

# %% [markdown]
# ### small model

# %%
nlp = pipeline("e2e-qg")
# Out:
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %%
df = pd.DataFrame(t) 
df.to_csv('test.csv')
from google.colab import files
files.download("test.csv")

# %%
d = d.rename(columns={ '0':'doc'})
d = d.dropna()

# %%
d.to_csv('test.csv')
from google.colab import files
files.download("test.csv")

# %%
d=pd.read_csv('test.csv')

# %%
d
# Out:
#      Unnamed: 0                                                doc
# 0             0  Who is looking for a new supply of cetirizine?...
# 1             1  What company makes the drug bromocriptine?', '...
# 2             2  What does nulytely hello can you tell me?', 'W...
# 3             3  What type of syndrome would i want to have my ...
# 4             4  In what year did my parents die with multiple ...
# ..          ...                                                ...
# 795         795  How many inguinal hernia do you offer on these...
# 796         796  What is pti?', 'What does removing the spleen ...
# 797         797  When was i diagnosed with anti kidd jk5?', 'Ho...
# 798         798  "What is the name of my cousin's elder father ...
# 799         799  What do you need to find information about kid...
#
# [796 rows x 2 columns]

# %%
import re
d['doc'] = d['doc'].str.replace("  ",'')

# %%
d['doc'][2]
# Out:
# 'What does nulytely hello can you tell me Who is the manufacture what phone number can i call thanks for What is the name of the phone number that can you call'

# %%
nlp(text2)
# Out:
# Your max_length is set to 256, but you input_length is only 161. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# ['What is the Latin word for gravitas?',
#  'What does gravity give weight to on Earth?',
#  "The Moon's gravity causes what?",
#  'Gravity has an infinite range, but its effects become weaker as objects get further away?']

# %%
nlp(text4)
# Out:
# Your max_length is set to 256, but you input_length is only 135. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# ['Who directed the 1994 American comedy-drama film Forrest Gump?',
#  'What is the name of the 1986 film that stars Tom Hanks, Robin Wright, Gary Sinise, Mykelti Williamson, and Sally Field?',
#  'Who is the author of the 1994 film forrest gump? What is Forrest a film that is based on?']

# %% [markdown]
# ### base-model

# %%
nlp = pipeline("e2e-qg", model="valhalla/t5-base-e2e-qg")
# Out:
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/195 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
nlp(text)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# ['Who created Python?',
#  'When was Python first released?',
#  "What is Python's design philosophy?"]

# %%
similar=[]

for j in range(800):
 paraphrase = []
 a = nlp(j)
 paraphrase.append(a)
#creating the second split
 paraphrase2 = [' '.join(x) for x in paraphrase]
# Combine the above splitted lists into a paragraph
 paraphrase3 = [' '.join(x for x in paraphrase2) ]
 paraphrased_text = str(paraphrase3).strip('[]').strip("'")
#paraphrased_text
 similar.append(paraphrased_text)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size

# %%
df = pd.DataFrame(similar) 
df.to_csv('ngen.csv')

# %%
from google.colab import files
files.download("ngen.csv")

# %%
print(df['document'][1])
# Out:
# who makes medicine i am wondering what company makes the drug bromocriptine i need it for a mass i have on my liver plate and the cost just keeps raising i cannot ever buy a full prescription because of the price and i was told if i get a hold of the maker of the drug sometimes they offer drugs or something to help me afford the medicine if i buy pills in which i have to take times a day it costs me and that is how i have to buy them thanks What is the name of the person who was asked to answer this question  How many questions did the person ask

# %%
for j in range(800):
  df['document'][j]=df['document'][j]+" "+similar[j]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#data['document']= data['document'].str.replace('\', ' ')
df['document']= df['document'].str.replace(',', ' ')
df['document']= df['document'].str.replace('"', ' ')
df['document']= df['document'].str.replace('  ', ' ')
df['document']= df['document'].str.replace('.', ' ')
df['document']= df['document'].str.replace('?', ' ')
df['document']= df['document'].str.replace("'", ' ')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df.to_csv('newgener.csv')
from google.colab import files
files.download("newgener.csv")
